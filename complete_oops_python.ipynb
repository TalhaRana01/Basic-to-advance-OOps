# %% [markdown]
# # Object Oriented Programming
#
# 1. Class
# 2. Object
# 3. Encapsulation
# 4. Inheritance
# 5. Polymorphism
# 6. Abstraction

# %% [markdown]
# ## Class
#
# - Blueprint | Structure
# - Self-defined datatypes
#
# **All data types are built in classes in Python**

# %% [markdown]
# ## Class main Hamsha 2 cheezain hoti hain
#
# 1. Data | Attributes Propertices
#
# - Example class Car attributes:
#   - Color
#   - Brand
#   - name
#   - top speed
#
# 2. Behavior | Menthod
#
# - Example calss Car Methods:
#   - accelerate()
#   - break()
#   - start()

# %%
a = 5

# %%
print(type(a))
# Its a class int
# Out:
# <class 'int'>

# %%
b = 10.5

# %%
print(type(b))
# Its a float class
# Out:
# <class 'float'>

# %%
c = "talha"
print(type(c))
# Its a string class
# Out:
# <class 'str'>

# %% [markdown]
# # Creating our Own Class

# %%
class Car:
  pass
